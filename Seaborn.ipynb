# %% [markdown]
# # Seaborn

# %% [markdown]
# Seaborn comes with a large number of high-level interfaces and customized themes that matplotlib lacks as it becomes difficult to figure out the settings that make plots attractive.
#
# Mostly, matplotlib functions don’t work well with dataframes as seaborn does.
#
# NB: Seaborn visualisations are based on matplotlib

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore') #to ignore warnings while runing the program

# %% [markdown]
# **Let's load a dataset to be used**  https://www.kaggle.com/datasets/rounakbanik/pokemon

# %%
ourdata=pd.read_csv('Pokemon.csv')

# %%
ourdata.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
sns.lmplot('Attack','Defense', data=ourdata) #lmplot() function is used to quickly plot the Linear Relationship between two(2) variables. lm for linear regression model
plt.show()

# %% [markdown]
# **No regression line and adding hue**

# %%
sns.lmplot('Attack','Defense',data=ourdata,fit_reg=False)

# %%
sns.lmplot('Attack','Defense',data=ourdata,fit_reg=False,hue='Legendary')

# %%
ourdata['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
ourdata.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=ourdata)
# Out:
# <AxesSubplot:>

# %%
#drop the unwanted columns 
ourdata1=ourdata.drop(['#','Total','Legendary','Generation'],axis=1)
ourdata1.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison  45      49       49       65
# 1                Ivysaur  Grass  Poison  60      62       63       80
# 2               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed
# 0       65     45
# 1       80     60
# 2      100     80
# 3      120     80
# 4       50     65

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data=ourdata1)
# Out:
# <AxesSubplot:>

# %%
corr = ourdata1.corr()  # Calculate correlations
 
corr
# Out:
#                HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.422386  0.239622  0.362380  0.378718  0.175952
# Attack   0.422386  1.000000  0.438687  0.396362  0.263990  0.381240
# Defense  0.239622  0.438687  1.000000  0.223549  0.510747  0.015227
# Sp. Atk  0.362380  0.396362  0.223549  1.000000  0.506121  0.473018
# Sp. Def  0.378718  0.263990  0.510747  0.506121  1.000000  0.259133
# Speed    0.175952  0.381240  0.015227  0.473018  0.259133  1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr)  # Creating Heatmap
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True,square=True)  #creating Heatmap
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Univariate Visualisation

# %% [markdown]
# ## DistPlot

# %% [markdown]
# The most convenient way to take a quick look at a univariate distribution in seaborn is the distplot() function. By default, this will draw a histogram and fit a kernel density estimate (KDE). It is used basically for univariant set of observations and visualizes it through a histogram i.e. only one observation and hence we choose one particular column of the dataset.

# %%
sns.distplot(ourdata1['Defense'])
# Out:
# <AxesSubplot:xlabel='Defense', ylabel='Density'>

# %%
sns.boxplot(ourdata1['Defense'])
# Out:
# <AxesSubplot:xlabel='Defense'>

# %%
sns.distplot(ourdata1['Defense'],kde=False)
# Out:
# <AxesSubplot:xlabel='Defense'>

# %% [markdown]
# **we can also use only the kde plot to plot only kde**

# %%
sns.kdeplot(ourdata1['Defense'])
plt.show()

# %% [markdown]
# **we can as well shade the kde for better visualisation by using shade=True**

# %%
sns.kdeplot(ourdata1['Defense'], shade=True)  #by saying shade=True allows you to shade the area under the curve for better view
plt.show()

# %% [markdown]
# ## Bivariate distributions-visualisations

# %% [markdown]
# **Jointplot**

# %%
ourdata.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
sns.jointplot(ourdata['Defense'], ourdata['Attack'])

# %% [markdown]
# As you can see a histogram plotted for Defense and another created for Attack, with a scatter plot created between Defense and Attack

# %% [markdown]
# **We can also explicitly set the 'kind' of visualisation to be displayed**
#
# e.g: kind= “scatter” or “reg” or “resid” or “kde” or “hex”

# %%
#NB: use shift and tab to get more info about a particular function

sns.jointplot(ourdata['Defense'], ourdata['Attack'], kind='kde')
plt.show()

# %%
sns.jointplot(ourdata['Defense'], ourdata['Attack'], kind='reg')
plt.show()

#good when you want to explain the residuals

# %% [markdown]
# **Visaulising more than two variables: Pairwise Bivariate Distributions-Using Pairplot()**

# %%
sns.pairplot(ourdata[['Defense','Attack','HP']],kind='scatter')
plt.show()

# %% [markdown]
# **You can change the diagonal kind**
#
# Let's try diag_kind='kde'

# %%
sns.pairplot(ourdata[['Defense','Attack','HP']],kind='scatter',diag_kind='kde')
plt.show()

# %%
ourdata.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## Categorical Data Visualisation

# %%
data=pd.read_csv('Automobile.csv')

# %%
data.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %%
sns.stripplot(data['number_of_doors'], data['horsepower'])
# Out:
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>

# %% [markdown]
# Cars with 2 door are having higher horsepower than cars with 4 door

# %%
sns.boxplot(data['number_of_doors'], data['horsepower'])
# Out:
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.barplot(data['number_of_doors'], data['horsepower'])
# Out:
# <AxesSubplot:xlabel='number_of_doors', ylabel='horsepower'>

# %%
sns.countplot(data['fuel_type'])
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='count'>
